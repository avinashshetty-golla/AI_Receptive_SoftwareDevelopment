# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 272  D E C E M B E R         25       We Can Be Heroes
# 273  D E C E M B E R         25      News of the World
# 274  D E C E M B E R         25  One Night in Miami...
# 275  D E C E M B E R         25  Promising Young Woman
# 276  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# 4    Lionsgate / Barry Films / Tycor International ...
# ..                                                 ...
# 272  Netflix / Troublemaker Studios / Double R Prod...
# 273  Universal Pictures / Playtone / Perfect World ...
# 274                                     Amazon Studios
# 275          Focus Features / FilmNation Entertainment
# 276                             Netflix / Bron Studios
#
#                                          Cast and crew  \
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...
# 1    William Eubank (director); Brian Duffield, Ada...
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Jon Avnet (director/screenplay); Eric Nazarian...
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                                                 ...
# 272  Robert Rodriguez (director/screenplay); Priyan...
# 273  Paul Greengrass (director/screenplay); Luke Da...
# 274  Regina King (director); Kemp Powers (screenpla...
# 275  Emerald Fennell (director/screenplay); Carey M...
# 276  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  NaN
# 4                                                  [5]
# ..                                                 ...
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 272  [245]
# 273  [246]
# 274  [247]
# 275  [248]
# 276  [249]
#
# [277 rows x 7 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 272       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 273      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 274  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 275  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 276      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [277 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\golla\python\anaconda3\lib\site-packages (1.9.0)
# Requirement already satisfied: requests in c:\users\golla\python\anaconda3\lib\site-packages (from tmdbv3api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\golla\python\anaconda3\lib\site-packages (from requests->tmdbv3api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\golla\python\anaconda3\lib\site-packages (from requests->tmdbv3api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\golla\python\anaconda3\lib\site-packages (from requests->tmdbv3api) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\golla\python\anaconda3\lib\site-packages (from requests->tmdbv3api) (2023.7.22)

# %%
from tmdbv3api import TMDb,Movie
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'c28b1759fd2337a50743113e8e107860'

# %%
movie = Movie()

def get_genre(title):
    try:
        # Search for the movie by title
        search_results = movie.search(title)
        
        if search_results:
            movie_id = search_results[0].id
            response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb.api_key}')
            movie_data = response.json()
            
            # Extract genres from the movie data
            genres = [genre['name'] for genre in movie_data['genres']]
            return genres
        else:
            return np.NaN  # Return NaN if movie is not found
    except Exception as e:
        print(f"Error getting genre for {title}: {e}")
        return np.NaN  # Return NaN in case of any error

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                movie_title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 272       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 273      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 274  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 275  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 276      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                            genres     director_name  \
# 0                     [Horror, Mystery, Thriller]     Nicolas Pesce
# 1    [Horror, Science Fiction, Action, Adventure]    William Eubank
# 2                                        [Comedy]     Miguel Arteta
# 3                                         [Drama]         Jon Avnet
# 4                        [Crime, Thriller, Drama]    Anthony Jerjen
# ..                                            ...               ...
# 272             [Family, Action, Fantasy, Comedy]  Robert Rodriguez
# 273                   [Drama, Western, Adventure]   Paul Greengrass
# 274                                       [Drama]       Regina King
# 275                      [Thriller, Crime, Drama]   Emerald Fennell
# 276                                       [Drama]  Kornél Mundruczó
#
#               actor_1_name       actor_2_name     actor_3_name
# 0       Andrea Riseborough      Demián Bichir         John Cho
# 1          Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2          Tiffany Haddish         Rose Byrne      Salma Hayek
# 3             Richard Gere     Peter Dinklage   Walton Goggins
# 4            Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                     ...                ...              ...
# 272  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 273              Tom Hanks      Helena Zengel              NaN
# 274      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 275         Carey Mulligan         Bo Burnham      Alison Brie
# 276          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [277 rows x 7 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                movie_title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 272       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 273      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 274  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 275  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 276      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                            genres     director_name  \
# 0                     [Horror, Mystery, Thriller]     Nicolas Pesce
# 1    [Horror, Science Fiction, Action, Adventure]    William Eubank
# 2                                        [Comedy]     Miguel Arteta
# 3                                         [Drama]         Jon Avnet
# 4                        [Crime, Thriller, Drama]    Anthony Jerjen
# ..                                            ...               ...
# 272             [Family, Action, Fantasy, Comedy]  Robert Rodriguez
# 273                   [Drama, Western, Adventure]   Paul Greengrass
# 274                                       [Drama]       Regina King
# 275                      [Thriller, Crime, Drama]   Emerald Fennell
# 276                                       [Drama]  Kornél Mundruczó
#
#               actor_1_name       actor_2_name     actor_3_name
# 0       Andrea Riseborough      Demián Bichir         John Cho
# 1          Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2          Tiffany Haddish         Rose Byrne      Salma Hayek
# 3             Richard Gere     Peter Dinklage   Walton Goggins
# 4            Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                     ...                ...              ...
# 272  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 273              Tom Hanks      Helena Zengel              NaN
# 274      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 275         Carey Mulligan         Bo Burnham      Alison Brie
# 276          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [277 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 272  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 273   Paul Greengrass              Tom Hanks      Helena Zengel
# 274       Regina King      Kingsley Ben-Adir          Eli Goree
# 275   Emerald Fennell         Carey Mulligan         Bo Burnham
# 276  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                        genres  \
# 0           John Cho                   [Horror, Mystery, Thriller]
# 1    Jessica Henwick  [Horror, Science Fiction, Action, Adventure]
# 2        Salma Hayek                                      [Comedy]
# 3     Walton Goggins                                       [Drama]
# 4     Chandler Riggs                      [Crime, Thriller, Drama]
# ..               ...                                           ...
# 272    YaYa Gosselin             [Family, Action, Fantasy, Comedy]
# 273              NaN                   [Drama, Western, Adventure]
# 274      Aldis Hodge                                       [Drama]
# 275      Alison Brie                      [Thriller, Crime, Drama]
# 276     Molly Parker                                       [Drama]
#
#                movie_title
# 0               The Grudge
# 1               Underwater
# 2              Like a Boss
# 3            Three Christs
# 4        Inherit the Viper
# ..                     ...
# 272       We Can Be Heroes
# 273      News of the World
# 274  One Night in Miami...
# 275  Promising Young Woman
# 276      Pieces of a Woman
#
# [277 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'].astype(str) + ' ' + \
                    new_df20['actor_2_name'].astype(str) + ' ' + \
                    new_df20['actor_3_name'].astype(str) + ' ' + \
                    new_df20['director_name'].astype(str) + ' ' + \
                    new_df20['genres'].apply(lambda x: ' '.join(x) if isinstance(x, list) else str(x))

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      5
# actor_3_name     28
# genres            2
# movie_title       0
# comb              0
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# C:\Users\golla\AppData\Local\Temp\ipykernel_34044\2267385682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 271       Pete Docter             Jamie Foxx           Tina Fey
# 272  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 274       Regina King      Kingsley Ben-Adir          Eli Goree
# 275   Emerald Fennell         Carey Mulligan         Bo Burnham
# 276  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                        genres  \
# 0           John Cho                   [Horror, Mystery, Thriller]
# 1    Jessica Henwick  [Horror, Science Fiction, Action, Adventure]
# 2        Salma Hayek                                      [Comedy]
# 3     Walton Goggins                                       [Drama]
# 4     Chandler Riggs                      [Crime, Thriller, Drama]
# ..               ...                                           ...
# 271    Graham Norton          [Animation, Family, Comedy, Fantasy]
# 272    YaYa Gosselin             [Family, Action, Fantasy, Comedy]
# 274      Aldis Hodge                                       [Drama]
# 275      Alison Brie                      [Thriller, Crime, Drama]
# 276     Molly Parker                                       [Drama]
#
#                movie_title                                               comb
# 0               the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1               underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3            three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4        inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                     ...                                                ...
# 271                   soul  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 272       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 274  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 275  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 276      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [248 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#                       director_name       actor_1_name          actor_2_name  \
# 0    Joachim Rønning Espen Sandberg        Johnny Depp         Javier Bardem
# 1                       Zack Snyder        Ben Affleck          Henry Cavill
# 2                     Taika Waititi    Chris Hemsworth        Tom Hiddleston
# 3                        James Gunn        Chris Pratt           Zoe Saldana
# 4                     Sean McNamara     Pierce Brosnan          William Hurt
# ..                              ...                ...                   ...
# 952          Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 953                    Greta Gerwig      Saoirse Ronan           Emma Watson
# 954                      Sam Mendes      George MacKay  Dean-Charles Chapman
# 955           Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 956                 Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#         actor_3_name                                    genres  \
# 0      Geoffrey Rush           Adventure Action Fantasy Comedy
# 1          Gal Gadot           Action Adventure Fantasy Sci-Fi
# 2     Cate Blanchett           Action Adventure Fantasy Sci-Fi
# 3      Dave Bautista            Action Adventure Comedy Sci-Fi
# 4    Benjamin Walker                  Fantasy Action Adventure
# ..               ...                                       ...
# 952    Rashida Jones  Animation Action Adventure Comedy Family
# 953    Florence Pugh                     Drama Romance History
# 954      Mark Strong                War History Thriller Drama
# 955      Brie Larson                       Drama Crime History
# 956      Aldis Hodge                                     Drama
#
#                                           movie_title  \
# 0    pirates of the caribbean: dead men tell no tales
# 1                                      justice league
# 2                                      thor: ragnarok
# 3                      guardians of the galaxy vol. 2
# 4                                 the king's daughter
# ..                                                ...
# 952                                 spies in disguise
# 953                                      little women
# 954                                              1917
# 955                                        just mercy
# 956                                          clemency
#
#                                                   comb
# 0    Johnny Depp Javier Bardem Geoffrey Rush Joachi...
# 1    Ben Affleck Henry Cavill Gal Gadot Zack Snyder...
# 2    Chris Hemsworth Tom Hiddleston Cate Blanchett ...
# 3    Chris Pratt Zoe Saldana Dave Bautista James Gu...
# 4    Pierce Brosnan William Hurt Benjamin Walker Se...
# ..                                                 ...
# 952  Will Smith Tom Holland Rashida Jones Nick Brun...
# 953  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 954  George MacKay Dean-Charles Chapman Mark Strong...
# 955  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 956  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [957 rows x 7 columns]

# %%
final_df = pd.concat([old_df, new_df20], ignore_index=True)

# %%
final_df
# Out:
#                        director_name           actor_1_name    actor_2_name  \
# 0     Joachim Rønning Espen Sandberg            Johnny Depp   Javier Bardem
# 1                        Zack Snyder            Ben Affleck    Henry Cavill
# 2                      Taika Waititi        Chris Hemsworth  Tom Hiddleston
# 3                         James Gunn            Chris Pratt     Zoe Saldana
# 4                      Sean McNamara         Pierce Brosnan    William Hurt
# ...                              ...                    ...             ...
# 1200                     Pete Docter             Jamie Foxx        Tina Fey
# 1201                Robert Rodriguez  Priyanka Chopra Jonas    Pedro Pascal
# 1202                     Regina King      Kingsley Ben-Adir       Eli Goree
# 1203                 Emerald Fennell         Carey Mulligan      Bo Burnham
# 1204                Kornél Mundruczó          Vanessa Kirby    Shia LaBeouf
#
#          actor_3_name                                genres  \
# 0       Geoffrey Rush       Adventure Action Fantasy Comedy
# 1           Gal Gadot       Action Adventure Fantasy Sci-Fi
# 2      Cate Blanchett       Action Adventure Fantasy Sci-Fi
# 3       Dave Bautista        Action Adventure Comedy Sci-Fi
# 4     Benjamin Walker              Fantasy Action Adventure
# ...               ...                                   ...
# 1200    Graham Norton  [Animation, Family, Comedy, Fantasy]
# 1201    YaYa Gosselin     [Family, Action, Fantasy, Comedy]
# 1202      Aldis Hodge                               [Drama]
# 1203      Alison Brie              [Thriller, Crime, Drama]
# 1204     Molly Parker                               [Drama]
#
#                                            movie_title  \
# 0     pirates of the caribbean: dead men tell no tales
# 1                                       justice league
# 2                                       thor: ragnarok
# 3                       guardians of the galaxy vol. 2
# 4                                  the king's daughter
# ...                                                ...
# 1200                                              soul
# 1201                                  we can be heroes
# 1202                             one night in miami...
# 1203                             promising young woman
# 1204                                 pieces of a woman
#
#                                                    comb
# 0     Johnny Depp Javier Bardem Geoffrey Rush Joachi...
# 1     Ben Affleck Henry Cavill Gal Gadot Zack Snyder...
# 2     Chris Hemsworth Tom Hiddleston Cate Blanchett ...
# 3     Chris Pratt Zoe Saldana Dave Bautista James Gu...
# 4     Pierce Brosnan William Hurt Benjamin Walker Se...
# ...                                                 ...
# 1200  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 1201  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 1202  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 1203  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 1204  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [1205 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
